# %%
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#Загружаем данные
data = './beverage_r.csv'
df = pd.read_csv(data, delimiter=';')
np.random.seed(42)
df
# Out:
#     numb.obs  COKE  D_COKE  D_PEPSI  D_7UP  PEPSI  SPRITE  TAB  SEVENUP
# 0          1     1       0        0      0      1       1    0        1
# 1          2     1       0        0      0      1       0    0        0
# 2          3     1       0        0      0      1       0    0        0
# 3          4     0       1        0      1      0       0    1        0
# 4          5     1       0        0      0      1       0    0        0
# 5          6     1       0        0      0      1       1    0        0
# 6          7     0       1        1      1      0       0    1        0
# 7          8     1       1        0      0      1       1    0        1
# 8          9     1       1        0      0      0       1    1        1
# 9         10     1       0        0      0      1       0    0        1
# 10        11     1       0        0      0      1       1    0        0
# 11        12     0       1        0      0      0       0    1        0
# 12        13     0       0        1      1      0       1    0        1
# 13        14     1       0        0      0      0       1    0        0
# 14        15     0       1        1      0      0       0    1        0
# 15        16     0       0        0      0      1       1    0        0
# 16        17     0       1        0      0      0       1    0        0
# 17        18     1       1        0      0      1       0    0        0
# 18        19     1       0        0      0      0       0    0        1
# 19        20     1       1        1      0      1       0    0        0
# 20        21     1       0        0      0      1       0    0        0
# 21        22     1       0        0      0      1       0    0        0
# 22        23     0       1        0      1      0       0    1        0
# 23        24     1       1        0      0      1       0    0        0
# 24        25     0       1        1      1      0       0    0        0
# 25        26     0       1        0      1      0       0    1        0
# 26        27     0       1        0      0      0       0    1        0
# 27        28     1       0        0      0      0       1    0        1
# 28        29     1       0        0      0      0       1    0        0
# 29        30     0       1        1      0      0       0    1        0
# 30        31     1       0        0      0      1       0    0        1
# 31        32     0       1        1      0      0       0    1        0
# 32        33     1       0        0      0      1       0    0        1
# 33        34     0       1        1      1      0       0    1        0

# %%
df_length = len(df)
print('Размер выборки: ', df_length)
# Out:
# Размер выборки:  34

# %% [markdown]
# # **Задача 1**
# Разделить таблицу данных так, чтобы в обучающую выборку попало 66% наблюдений, а в тестовую выборку 33% наблюдений

# %%
indices = list(range(df_length))
q66 = np.quantile(indices, 0.66)

np.random.shuffle(indices)
print('Перемешанные индексы: ', indices)
# Out:
# Перемешанные индексы:  [15, 19, 27, 26, 8, 24, 21, 12, 32, 9, 0, 4, 16, 17, 5, 13, 11, 1, 2, 30, 3, 29, 23, 31, 22, 18, 25, 6, 20, 33, 7, 10, 14, 28]

# %%
train = df[indices <= q66]
test = df[indices > q66]

print('обучающая выборка: ', len(train))
print('тестовая выборка: ', len(test))
# Out:
# обучающая выборка:  22
# тестовая выборка:  12

# %% [markdown]
# # **Задача 2**
# Разделить таблицу данных на четыре одинаковых части.

# %%
indices = list(range(df_length))
q1 = np.quantile(indices, 0.25)
q2 = np.quantile(indices, 0.5)
q3 = np.quantile(indices, 0.75)

np.random.shuffle(indices)
print('Новые индексы (после перемешивания): ', indices)
# Out:
# Новые индексы (после перемешивания):  [10, 7, 0, 23, 5, 21, 16, 12, 25, 28, 32, 9, 1, 13, 26, 24, 3, 17, 20, 8, 6, 33, 4, 2, 19, 22, 11, 18, 31, 30, 29, 14, 15, 27]

# %%
part1 = df[indices <= q1]
part2 = df[(indices > q1) & (indices <= q2)]
part3 = df[(indices > q2) & (indices <= q3)]
part4 = df[indices > q3]

print('Первая выборка: ', len(part1))
print('Вторая выборка: ', len(part2))
print('Третья выборка: ', len(part3))
print('Четвёртая выборка: ', len(part4))
# Out:
# Первая выборка:  9
# Вторая выборка:  8
# Третья выборка:  8
# Четвёртая выборка:  9

# %% [markdown]
# # **Задача 3**
# Разделить таблицу данных на две стратифицированные подвыборки.
# По переменным кока-кола и минералка.

# %%
from math import ceil
proportion = 0.85

df['strata'] = df['COKE'].astype(str) + '_' + df['TAB'].astype(str)

indices = np.array(range(df_length))
np.random.shuffle(indices)

train_indices = []


for strata_name, group in df.groupby('strata'):
    group_indices = group.index.to_list()
    n_train = int((len(group)) * proportion)
    np.random.shuffle(group_indices)
    train_indices.extend(group_indices[:n_train])

train = df.loc[train_indices]
test = df.drop(train_indices)

# %%
print("Исходные:\n", df[['COKE', 'TAB']].value_counts())
print("\nTrain:\n", train[['COKE', 'TAB']].value_counts())
print("\nTest:\n", test[['COKE', 'TAB']].value_counts())
# Out:
# Исходные:
#  COKE  TAB
# 1     0      19
# 0     1      10
#       0       4
# 1     1       1
# Name: count, dtype: int64
#
# Train:
#  COKE  TAB
# 1     0      16
# 0     1       8
#       0       3
# Name: count, dtype: int64
#
# Test:
#  COKE  TAB
# 1     0      3
# 0     1      2
#       0      1
# 1     1      1
# Name: count, dtype: int64
